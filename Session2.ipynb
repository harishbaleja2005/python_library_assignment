# %%
#1.Create a 2D NumPy array representing the ratings (out of 5) given by 4 users to 5 different food items on Zomato.
# Use slicing to extract the ratings given by the second and third users only.
import numpy as np

rating=np.array([[4.5,4,3,4,3.5],
                 [4,3.5,4.5,4,3],
                 [4,4.5,3,3.5,4],
                 [3,4.5,3.5,4,3]])

print("ratings given by the second and third users:")
print(rating[1:3])
# Out:
# ratings given by the second and third users:
# [[4.  3.5 4.5 4.  3. ]
#  [4.  4.5 3.  3.5 4. ]]

# %%
#2.Given a NumPy array of daily steps tracked for 10 days, use boolean indexing to select only the days where 
# the steps were greater than 8000.<br><br><em><strong>Hint:</strong> Use an array like steps = np.array([7500, 8200, 9000, ...]) and apply a boolean condition.</em>
import numpy as np
daily_steps=np.array([7500,6200,11000,10000,7000,6500,7200,12000,6800,8600])

print(daily_steps>8000)
print("days with steps greater than 8000:", daily_steps[daily_steps>8000])
# Out:
# [False False  True  True False False False  True False  True]
# days with steps greater than 8000: [11000 10000 12000  8600]

# %%
#3.Create a NumPy array of IPL team scores for 8 matches. Use fancy indexing to select the scores from matches
#  2, 5, and 7, and print them.
import numpy as np

team_score=np.array([180,210,190,200,220,170,160,190])

score=team_score[[1,4,6]]

print("scores from matches 2, 5, and 7:", score)
# Out:
# scores from matches 2, 5, and 7: [210 220 160]

# %%
#4.Suppose you have a NumPy array of product prices from Flipkart. Use broadcasting to apply a 10% discount to all
#  prices and print the new array.<br><br><em><strong>Constraint:</strong> Do not use any loops.</em>
import numpy as np

product_price=np.array([200,250,300,450,500,600])

discount=10

final_price=product_price-(product_price*discount/100)

print("final prices after 10% discount:", final_price)
# Out:
# final prices after 10% discount: [180. 225. 270. 405. 450. 540.]

# %%
#5.Given a NumPy array of user ratings (can be negative, zero, or positive) for songs on Spotify, use
# boolean masking to set all negative ratings to zero, keeping other ratings unchanged.
import numpy as np

spotify_rating=np.array([4,-3,3,0,-2,5,-3,0,5,4,-4])

spotify_rating[spotify_rating<0]=0

print("spotify ratings after setting negative values to zero:", spotify_rating)
# Out:
# spotify ratings after setting negative values to zero: [4 0 3 0 0 5 0 0 5 4 0]
