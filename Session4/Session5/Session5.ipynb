# %%
#1.Connect to a MySQL or PostgreSQL database using SQLAlchemy and pandas, then use pd.read_sql() to load the
# entire 'restaurants' table (imagine Zomato backend) into a DataFrame and display the first 5 rows.
from sqlalchemy import create_engine
import pandas as pd

engine=create_engine( "mysql+pymysql://root:""@localhost:3306/foodie_app")
data=pd.read_sql("select * from restaurants_record",engine)
data.head()
# Out:
#    restaurant_id restaurant_name       city       cuisine  rating  \
# 0              1     Spice Villa  Ahmedabad  North Indian     4.6
# 1              2       Pizza Hub  Ahmedabad       Italian     4.3
# 2              3    Burger Point  Ahmedabad     Fast Food     4.5
# 3              4   Royal Biryani  Ahmedabad       Biryani     4.7
# 4              5     South Treat  Ahmedabad  South Indian     4.2
#
#    delivery_charge
# 0               30
# 1               60
# 2               40
# 3               20
# 4               50

# %%
#2.Use pd.read_sql_query() to fetch only the 'name' and 'rating' columns from a 'movies' table (think BookMyShow-like data)
# where rating is above 8, and print the resulting DataFrame.<br><br><em><strong>Hint:</strong> Write a custom SQL SELECT query as the first argument to pd.read_sql_query().</em>
from sqlalchemy import create_engine
import pandas as pd

engine=create_engine("mysql+pymysql://root:""@localhost:3306/music_streaming_app")
data=pd.read_sql_query("select title as name,rating from movies where rating>8 ",engine)
print(data)
# Out:
#                 name  rating
# 0          Inception     8.8
# 1       Interstellar     8.7
# 2  Avengers: Endgame     8.4
# 3              Joker     8.5

# %%
#3.Read a JSON dataset from the URL https://jsonplaceholder.typicode.com/users using pandas, convert it into
# a DataFrame, and print the usernames column.<br><br><em><strong>Hint:</strong> Use pd.read_json() directly with the URL.</em>
import pandas as pd

data=pd.read_json(" https://jsonplaceholder.typicode.com/users")
print(data["username"])
# Out:
# 0                Bret
# 1           Antonette
# 2            Samantha
# 3            Karianne
# 4              Kamren
# 5    Leopoldo_Corkery
# 6        Elwyn.Skiles
# 7       Maxime_Nienow
# 8            Delphine
# 9      Moriah.Stanton
# Name: username, dtype: str

# %%
#4.You have two CSV files: 'orders.csv' (order_id, user_id, amount) and 'users.csv' (user_id, username). Load
# both into DataFrames using pathlib for file paths, then merge them on 'user_id' to show a combined table with username and amount.
import pandas as pd 
from pathlib import Path

orders_path=Path("orders.csv")
users_path=Path("users.csv")

orders=pd.read_csv(orders_path)
users=pd.read_csv(users_path)

combined=pd.merge(orders,users,on="user_id")

print(combined[["username","amount"]])
# Out:
#   username  amount
# 0    rohit     500
# 1    Rahul     700
# 2    rohit     300
# 3    Priya     900
# 4    Rahul     450

# %%
#5.Concatenate two DataFrames representing 'today_orders' and 'yesterday_orders' (each with columns: order_id,
# item, price), and display the combined DataFrame.<br><br><em><strong>Constraint:</strong> Use pd.concat() and reset the index after concatenation.</em>
import pandas as pd

today_orders=pd.DataFrame({
    "order_id":[101,102,103],
    "item":["Pizza", "Burger", "Biryani"],
    "price":[250, 180, 300]
})

yesterday_orders=pd.DataFrame({
    "order_id":[98,99,100],
    "item":["Pasta", "Sandwich", "Pizza"],
    "price":[220, 150, 250]
})

combined=pd.concat([yesterday_orders,today_orders])

combined=combined.reset_index(drop=True)

print(combined)
# Out:
#    order_id      item  price
# 0        98     Pasta    220
# 1        99  Sandwich    150
# 2       100     Pizza    250
# 3       101     Pizza    250
# 4       102    Burger    180
# 5       103   Biryani    300
